# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split, cross_val_score , GridSearchCV
from sklearn.utils.multiclass import unique_labels
from sklearn import metrics
import warnings
warnings.filterwarnings('ignore')

# %%
#importing train_test_split
from sklearn.model_selection import train_test_split

# %%
data = pd.read_excel("StateCodeReduced.xlsx")

# %%
data.head()

# %%
data['code'].value_counts()

# %%
data.isnull().sum()

# %%
data.corr()

# %%
X = data[["mw","temp","moisture","mvar","mw_declare","unit_no"]]
y = data["code"]
y

# %%
scaler = StandardScaler()
X = pd.DataFrame(scaler.fit_transform(X), columns = X.columns)
X

# %%
import seaborn as sns
import matplotlib.pyplot as plt
data.code.value_counts().plot(kind='bar')
plt.xlabel("Success or Not")
plt.ylabel("Count")
plt.title("Success ")

# %%
sns.countplot(y)
# Out:
# <AxesSubplot:xlabel='code', ylabel='count'>

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 0)

# %%
#Setup a knn classifier with k neighbors
Model = SVC()

# %%
#Fit the model
Model.fit(X_train,y_train)
# Out:
# SVC()

# %%
Model.score(X_test,y_test) # Accuracy of the model
# Out:
# 0.7670006612074666

# %%
Model.score(X_train,y_train) # Accuracy of the model
# Out:
# 0.77416401447443

# %%
y_pred = Model.predict(X_test)

# %%
#import confusion_matrix
from sklearn.metrics import confusion_matrix
mat = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(20, 20))
sns.heatmap(mat, annot=True)
# Out:
# <AxesSubplot:>

# %%
#import classification_report
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#           FA       0.22      0.03      0.05        69
#           FG       0.00      0.00      0.00         2
#          FG1       0.00      0.00      0.00        17
#           FO       0.86      0.13      0.23       145
#           FP       0.52      0.41      0.46       166
#           FQ       0.00      0.00      0.00        77
#           LA       0.85      0.42      0.56       178
#           LD       0.73      0.37      0.49        51
#          LF1       0.72      0.43      0.54      4897
#          LF2       0.00      0.00      0.00         1
#           LG       0.00      0.00      0.00         1
#          LG1       0.00      0.00      0.00         2
#          LG3       0.00      0.00      0.00        45
#          LG5       0.00      0.00      0.00        30
#           LP       0.78      0.95      0.86       703
#           LQ       0.88      0.46      0.60        46
#           PA       0.00      0.00      0.00         9
#           PM       0.86      0.60      0.71       342
#           PO       0.74      0.98      0.84      1886
#            R       0.00      0.00      0.00       154
#         RLF1       0.00      0.00      0.00         6
#          RLP       0.00      0.00      0.00        17
#           SO       0.78      0.93      0.85     10817
#
#     accuracy                           0.77     19661
#    macro avg       0.35      0.25      0.27     19661
# weighted avg       0.75      0.77      0.74     19661

# %%
param_grid = [
  {'C': [1, 10, 100, 1000], 'kernel': ['linear']},
  {'C': [1, 10, 100, 1000], 'gamma': [0.001, 0.0001], 'kernel': ['rbf']},
 ]

# %%
svc = SVC()
gs = GridSearchCV(estimator=svc,param_grid=param_grid,scoring="accuracy", cv=10)
grid_search = gs.fit(X_train,y_train)
best_score = grid_search.best_score_
best_parameters = grid_search.best_params_
print("Best Score:",best_score)
print("Best Parameters:",best_parameters)

# %%
Model = SVC(**best_parameters)

# %%
dt_acc = metrics.accuracy_score(y_test, y_pred)
print(dt_acc)
